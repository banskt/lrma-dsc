# %%
import numpy as np
import pandas as pd
import pickle
import sys
import os
import dsc
from dsc.query_engine import Query_Processor as dscQP
from dsc import dsc_io

import matplotlib.pyplot as plt
from pymir import mpl_stylesheet
from pymir import mpl_utils
mpl_stylesheet.banskt_presentation(splinecolor = 'black', dpi = 120)

sys.path.append("/gpfs/commons/home/sbanerjee/work/npd/lrma-dsc/post-process")
import dscrutils2py as dscrutils
# Out:
# INFO: cffi mode is CFFI_MODE.ANY
# INFO: R home found: /nfs/sw/easybuild/software/custom-conda/R-4.4.3/lib/R
# INFO: R library path: /nfs/sw/easybuild/software/FlexiBLAS/3.3.1-GCC-13.2.0/lib:/nfs/sw/easybuild/software/OpenBLAS/0.3.24-GCC-13.2.0/lib:/nfs/sw/easybuild/software/binutils/2.40-GCCcore-13.2.0/lib:/nfs/sw/easybuild/software/zlib/1.2.13-GCCcore-13.2.0/lib:/nfs/sw/easybuild/software/GCCcore/13.2.0/lib64:/nfs/sw/easybuild/software/custom-conda/R-4.4.3/lib:/opt/slurm/slurm-24.05.2/lib:/opt/slurm/slurm-24.05.2/lib/slurm::
# INFO: LD_LIBRARY_PATH: /nfs/sw/easybuild/software/FlexiBLAS/3.3.1-GCC-13.2.0/lib:/nfs/sw/easybuild/software/OpenBLAS/0.3.24-GCC-13.2.0/lib:/nfs/sw/easybuild/software/binutils/2.40-GCCcore-13.2.0/lib:/nfs/sw/easybuild/software/zlib/1.2.13-GCCcore-13.2.0/lib:/nfs/sw/easybuild/software/GCCcore/13.2.0/lib64:/nfs/sw/easybuild/software/custom-conda/R-4.4.3/lib:/opt/slurm/slurm-24.05.2/lib:/opt/slurm/slurm-24.05.2/lib/slurm
# INFO: Default options to initialize R: rpy2, --quiet, --no-save
# INFO: R is already initialized. No need to initialize.

# %%
def stratify_dfcol(df, colname, value):
    #return pd_utils.select_dfrows(df, [f"$({colname}) == {value}"])
    return df.loc[df[colname] == value]

def stratify_dfcols(df, condition_list):
    for (colname, value) in condition_list:
        df = stratify_dfcol(df, colname, value)
    return df

def stratify_dfcols_in_list(df, colname, values):
    return df.loc[df[colname].isin(values)]

# %%
dsc_output = "/gpfs/commons/groups/knowles_lab/sbanerjee/low_rank_matrix_approximation_numerical_experiments/lrma"
dsc_fname  = os.path.basename(os.path.normpath(dsc_output))
db = os.path.join(dsc_output, dsc_fname + ".db")
# dscoutpkl = os.path.join("/gpfs/commons/home/sbanerjee/work/npd/lrma-dsc/dsc/results", dsc_fname + "_dscout.pkl")
# dscout    = pd.read_pickle(dscoutpkl)
# dscout

# %%
targets = ["simulate"] + \
            [f"simulate.{x}" for x in ["n", "p", "k", "h2", "h2_shared_frac", "aq"]] + \
            ["lowrankfit", "mfmethods"] + \
            [f"score.{x}" for x in ["L_rmse"]] # all scores have same output file

qp = dscQP(db, targets)
df = qp.output_table
df
# Out:
#       DSC      simulate  simulate.p          simulate.output.file  simulate.n  \
# 0       1     blockdiag      2000.0         blockdiag/blockdiag_1       200.0
# 1       2     blockdiag      2000.0         blockdiag/blockdiag_2       200.0
# 2       3     blockdiag      2000.0         blockdiag/blockdiag_3       200.0
# 3       4     blockdiag      2000.0         blockdiag/blockdiag_4       200.0
# 4       5     blockdiag      2000.0         blockdiag/blockdiag_5       200.0
# ...   ...           ...         ...                           ...         ...
# 1705    8  blockdiag_aq      2000.0  blockdiag_aq/blockdiag_aq_16       200.0
# 1706    9  blockdiag_aq      2000.0  blockdiag_aq/blockdiag_aq_17       200.0
# 1707    9  blockdiag_aq      2000.0  blockdiag_aq/blockdiag_aq_18       200.0
# 1708   10  blockdiag_aq      2000.0  blockdiag_aq/blockdiag_aq_19       200.0
# 1709   10  blockdiag_aq      2000.0  blockdiag_aq/blockdiag_aq_20       200.0
#
#       simulate.k  simulate.h2_shared_frac  simulate.h2  simulate.aq  \
# 0           10.0                      0.6          0.2          0.6
# 1           10.0                      0.6          0.2          0.6
# 2           10.0                      0.6          0.2          0.6
# 3           10.0                      0.6          0.2          0.6
# 4           10.0                      0.6          0.2          0.6
# ...          ...                      ...          ...          ...
# 1705        10.0                      0.6          0.2          0.8
# 1706        10.0                      0.6          0.2          0.4
# 1707        10.0                      0.6          0.2          0.8
# 1708        10.0                      0.6          0.2          0.4
# 1709        10.0                      0.6          0.2          0.8
#
#      lowrankfit   lowrankfit.output.file      mfmethods  \
# 0          rpca  rpca/blockdiag_1_rpca_1  truncated_svd
# 1          rpca  rpca/blockdiag_2_rpca_1  truncated_svd
# 2          rpca  rpca/blockdiag_3_rpca_1  truncated_svd
# 3          rpca  rpca/blockdiag_4_rpca_1  truncated_svd
# 4          rpca  rpca/blockdiag_5_rpca_1  truncated_svd
# ...         ...                      ...            ...
# 1705         NA                       NA       factorgo
# 1706         NA                       NA       factorgo
# 1707         NA                       NA       factorgo
# 1708         NA                       NA       factorgo
# 1709         NA                       NA       factorgo
#
#                                  mfmethods.output.file  \
# 0     truncated_svd/blockdiag_1_rpca_1_truncated_svd_1
# 1     truncated_svd/blockdiag_2_rpca_1_truncated_svd_1
# 2     truncated_svd/blockdiag_3_rpca_1_truncated_svd_1
# 3     truncated_svd/blockdiag_4_rpca_1_truncated_svd_1
# 4     truncated_svd/blockdiag_5_rpca_1_truncated_svd_1
# ...                                                ...
# 1705   factorgo/blockdiag_aq_16_identical_1_factorgo_1
# 1706   factorgo/blockdiag_aq_17_identical_1_factorgo_1
# 1707   factorgo/blockdiag_aq_18_identical_1_factorgo_1
# 1708   factorgo/blockdiag_aq_19_identical_1_factorgo_1
# 1709   factorgo/blockdiag_aq_20_identical_1_factorgo_1
#
#                                     score.L_rmse:output
# 0     score/blockdiag_61_rpca_7_truncated_svd_7_score_7
# 1     score/blockdiag_62_rpca_7_truncated_svd_7_score_7
# 2     score/blockdiag_63_rpca_7_truncated_svd_7_score_7
# 3     score/blockdiag_64_rpca_7_truncated_svd_7_score_7
# 4     score/blockdiag_65_rpca_7_truncated_svd_7_score_7
# ...                                                 ...
# 1705  score/blockdiag_aq_136_identical_7_factorgo_7_...
# 1706  score/blockdiag_aq_137_identical_7_factorgo_7_...
# 1707  score/blockdiag_aq_138_identical_7_factorgo_7_...
# 1708  score/blockdiag_aq_139_identical_7_factorgo_7_...
# 1709  score/blockdiag_aq_140_identical_7_factorgo_7_...
#
# [1710 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['DSC', 'simulate', 'simulate.p', 'simulate.output.file', 'simulate.n',
#        'simulate.k', 'simulate.h2_shared_frac', 'simulate.h2', 'simulate.aq',
#        'lowrankfit', 'lowrankfit.output.file', 'mfmethods',
#        'mfmethods.output.file', 'score.L_rmse:output'],
#       dtype='object')

# %%
df.loc[[190]]
# Out:
#      DSC     simulate  simulate.p       simulate.output.file  simulate.n  \
# 190    1  blockdiag_k      2000.0  blockdiag_k/blockdiag_k_1       200.0
#
#      simulate.k  simulate.h2_shared_frac  simulate.h2  simulate.aq lowrankfit  \
# 190         2.0                      0.6          0.2          0.6        nnm
#
#       lowrankfit.output.file      mfmethods  \
# 190  nnm/blockdiag_k_1_nnm_1  truncated_svd
#
#                                  mfmethods.output.file  \
# 190  truncated_svd/blockdiag_k_1_nnm_1_truncated_svd_1
#
#                                    score.L_rmse:output
# 190  score/blockdiag_k_241_nnm_7_truncated_svd_7_sc...

# %%
df.loc[190]
# Out:
# DSC                                                                        1
# simulate                                                         blockdiag_k
# simulate.p                                                            2000.0
# simulate.output.file                               blockdiag_k/blockdiag_k_1
# simulate.n                                                             200.0
# simulate.k                                                               2.0
# simulate.h2_shared_frac                                                  0.6
# simulate.h2                                                              0.2
# simulate.aq                                                              0.6
# lowrankfit                                                               nnm
# lowrankfit.output.file                               nnm/blockdiag_k_1_nnm_1
# mfmethods                                                      truncated_svd
# mfmethods.output.file      truncated_svd/blockdiag_k_1_nnm_1_truncated_svd_1
# score.L_rmse:output        score/blockdiag_k_241_nnm_7_truncated_svd_7_sc...
# Name: 190, dtype: object

# %%
mf_res    = dsc_io.load_dsc(os.path.join(dsc_output, "guide/blockdiag_k_2_identical_1_guide_1.pkl"))
sim_input = dsc_io.load_dsc(os.path.join(dsc_output, "blockdiag_k/blockdiag_k_2.pkl"))

# %%
mf_res.keys()
# Out:
# dict_keys(['L_est', 'F_est', 'S2', 'DSC_DEBUG'])

# %%
sim_input.keys()
# Out:
# dict_keys(['Z', 'Zmask', 'effect_size_obs', 'effect_size_true', 'Ltrue', 'Ftrue', 'Mtrue', 'Ctrue', 'nsample', 'DSC_DEBUG'])

# %%
sys.path.append("/gpfs/commons/home/sbanerjee/work/npd/lrma-dsc/dsc/functions")

from comparison_metrics import matrix_dissimilarity_scores
from comparison_metrics import adjusted_mutual_information_score
from comparison_metrics import root_mean_squared_error
from comparison_metrics import peak_signal_to_noise_ratio
from comparison_metrics import standardize

# %%
Ltrue = sim_input["Ltrue"]
Ftrue = sim_input["Ftrue"]
labels = sim_input["Ctrue"]
L = gleanr_res["L_est"]
F = gleanr_res["F_est"]

# %%
L_rmse, L_psnr = matrix_dissimilarity_scores(Ltrue, L)
F_rmse, F_psnr = matrix_dissimilarity_scores(Ftrue, F)
Ztrue = standardize(Ltrue @ Ftrue.T, axis = 0)
Zrecv = standardize(L @ F.T, axis = 0)
Z_rmse = root_mean_squared_error(Ztrue, Zrecv)
Z_psnr = peak_signal_to_noise_ratio(Ztrue, Zrecv)
MI, adj_MI = adjusted_mutual_information_score(L, labels)

# %%
Z_rmse
# Out:
# 0.9123679256846536

# %%
dscout = dscrutils.dscquery(dsc_output, targets)
# Out:
# Calling: dsc-query /gpfs/commons/groups/knowles_lab/sbanerjee/low_rank_matrix_approximation_numerical_experiments/lrma_pilot -o /tmp/Rtmppllmze/file1125aa571280c2.csv --target "simulate simulate.n simulate.p simulate.k simulate.h2 simulate.h2_shared_frac simulate.aq lowrankfit mfmethods score.L_rmse score.F_rmse score.Z_rmse score.L_psnr score.F_psnr score.Z_psnr score.adj_MI" --force
# Loaded dscquery output table with 6 rows and 20 columns.

# %%
dscout
# Out:
#    DSC   simulate  simulate.n  simulate.p  simulate.k  simulate.h2
# 0    1  blockdiag         200         500          10          0.2  \
# 1    1  blockdiag         200         500          10          0.2
# 2    1  blockdiag         200         500          10          0.2
# 3    1  blockdiag         200         500          10          0.2
# 4    1  blockdiag         200         500          10          0.2
# 5    1  blockdiag         200         500          10          0.2
#
#    simulate.h2_shared_frac  simulate.aq  lowrankfit      mfmethods
# 0                      0.5          0.6        rpca  truncated_svd  \
# 1                      0.5          0.6         nnm  truncated_svd
# 2                      0.5          0.6  nnm_sparse  truncated_svd
# 3                      0.5          0.6        None  truncated_svd
# 4                      0.5          0.6        None       factorgo
# 5                      0.5          0.6        None       flashier
#
#    score.L_rmse  score.F_rmse  score.Z_rmse  score.L_psnr  score.F_psnr
# 0      0.318090      0.358677      0.007440     26.348389     26.053003  \
# 1      0.343524      0.371516      0.007744     25.680260     25.747526
# 2      0.343298      0.371412      0.007745     25.685974     25.749952
# 3      0.346300      0.371384      0.006549     25.610347     25.750614
# 4      0.401745      0.497179      0.004205     24.320396     23.216812
# 5      0.361294      0.428657      1.678715     25.242177     24.504877
#
#    score.Z_psnr  score.adj_MI
# 0     24.850847      0.834796
# 1     24.503876      0.820669
# 2     24.501851      0.828367
# 3     25.959193      0.006741
# 4     29.806612      0.017130
# 5    -22.216785      0.042308
